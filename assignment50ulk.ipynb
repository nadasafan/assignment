# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('50ulke.csv')
df.head()
# Out:
#    Unnamed: 0       Countries  National Income  Growth  Per person  \
# 0           0   United States         20412.87    2.27     62152.0
# 1           1           China         14092.51    6.86     10088.0
# 2           2           Japan          5167.05    1.71     40849.0
# 3           3         Germany          4211.64    2.51     50842.0
# 4           4  United Kingdom          2936.29    1.79     44177.0
#
#        Continent
# 0  North America
# 1           Asia
# 2           Asia
# 3         Europe
# 4         Europe

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df.head()
# Out:
#         Countries  National Income  Growth  Per person      Continent
# 0   United States         20412.87    2.27     62152.0  North America
# 1           China         14092.51    6.86     10088.0           Asia
# 2           Japan          5167.05    1.71     40849.0           Asia
# 3         Germany          4211.64    2.51     50842.0         Europe
# 4  United Kingdom          2936.29    1.79     44177.0         Europe

# %%
df.sort_values('Per person',ascending=True)
# Out:
#                    Countries  National Income  Growth  Per person  \
# 40                  Pakistan           324.73    5.28      1615.0
# 21                    Poland           614.19    4.55      1618.0
# 42                Bangladesh           285.82    7.14      1734.0
# 30                   Nigeria           408.61    0.82      2108.0
# 6                      India          2848.23    6.74      2135.0
# 18              Saudi Arabia           748.00   -0.74      2265.0
# 45            Czech Republic           251.58    4.29      2375.0
# 48                   Vietnam           240.78    6.81      2546.0
# 44                     Egypt           253.25    4.23      2611.0
# 38               Philippines           332.45    6.67      3095.0
# 15                 Indonesia          1074.97    5.07      4052.0
# 28  Islamic Republic of Iran           418.88    4.28      5086.0
# 34                   Denmark           369.76    2.11      6383.0
# ...

# %%
print(df.shape)
# Out:
# (50, 5)

# %% [markdown]
# From the output, we can see that the table contains 50 rows and 6columns.
#
# Now let's try printing out column names using columns:

# %%
print(df.columns)
# Out:
# Index(['Countries', 'National Income', 'Growth', 'Per person', 'Continent'], dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Countries        50 non-null     object
#  1   National Income  50 non-null     float64
#  2   Growth           50 non-null     float64
#  3   Per person       50 non-null     float64
#  4   Continent        50 non-null     object
# dtypes: float64(3), object(2)
# memory usage: 2.1+ KB
# None

# %% [markdown]
# The describe method shows basic statistical characteristics of each numerical feature

# %%
df.describe()
# Out:
#        National Income     Growth    Per person
# count        50.000000  50.000000     50.000000
# mean       1646.348200   3.320400  27696.000000
# std        3448.554429   2.053468  25094.131496
# min         231.570000  -0.740000   1615.000000
# 25%         353.440000   1.795000   6402.000000
# 50%         522.985000   2.880000  14565.500000
# 75%        1504.895000   4.287500  48738.250000
# max       20412.870000   7.810000  86835.000000

# %%
df['Growth'] =df['Growth'].apply(lambda x: abs(x))

# %%
df.describe()
# Out:
#        National Income     Growth    Per person
# count        50.000000  50.000000     50.000000
# mean       1646.348200   3.350000  27696.000000
# std        3448.554429   2.003811  25094.131496
# min         231.570000   0.530000   1615.000000
# 25%         353.440000   1.795000   6402.000000
# 50%         522.985000   2.880000  14565.500000
# 75%        1504.895000   4.287500  48738.250000
# max       20412.870000   7.810000  86835.000000

# %%
df.describe(include=['object'])
# Out:
#        Countries Continent
# count         50        50
# unique        50         6
# top      Denmark    Europe
# freq           1        19

# %% [markdown]
# For categorical (type object)feature we can use the value_counts method. Let's have a look at the distribution of Continent:

# %%
df['Continent'].value_counts()
# Out:
# Europe           19
# Asia             19
# South America     5
# North America     3
# Africa            3
# Oceania           1
# Name: Continent, dtype: int64

# %%
df['Growth']
# Out:
# 0     2.27
# 1     6.86
# 2     1.71
# 3     2.51
# 4     1.79
# 5     1.85
# 6     6.74
# 7     1.47
# 8     0.98
# 9     3.00
# 10    1.55
# 11    3.09
# 12    3.05
# 13    2.27
# 14    2.04
# 15    5.07
# 16    3.11
# 17    7.05
# 18    0.74
# 19    1.07
# 20    2.86
# 21    4.55
# 22    2.79
# 23    2.40
# 24    1.71
# 25    3.90
# 26    2.90
# 27    1.81
# 28    4.28
# 29    0.53
# 30    0.82
# 31    7.81
# 32    3.32
# 33    1.32
# 34    2.11
# 35    5.90
# 36    3.82
# 37    3.62
# 38    6.67
# 39    1.77
# 40    5.28
# 41    2.99
# 42    7.14
# 43    1.47
# 44    4.23
# 45    4.29
# 46    2.67
# 47    7.00
# 48    6.81
# 49    2.51
# Name: Growth, dtype: float64

# %%
df['Growth'].mean()
# Out:
# 3.3499999999999996

# %% [markdown]
# What are average values of numerical features

# %%
df[df['Growth'] == 2.51].mean()
# Out:
# National Income     2221.605
# Growth                 2.510
# Per person         29020.500
# dtype: float64

# %% [markdown]
# Applying Functions to Cells, Columns and Rows
# To apply functions to each column, use apply():

# %%
df.apply(np.max)
# Out:
# Countries                Vietnam
# National Income          20412.9
# Growth                      7.81
# Per person                 86835
# Continent          South America
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(y='Continent',hue='Continent', data=df );

# %%
df['Continent'].value_counts()
# Out:
# Europe           19
# Asia             19
# South America     5
# North America     3
# Africa            3
# Oceania           1
# Name: Continent, dtype: int64

# %%
sns.countplot(x='Continent', data=df);

# %% [markdown]
# Asia and Europ have 18 Countries more than anthor Continent
# Oceania have 1

# %%
df.sort_values("National Income", ascending=True)['National Income']
# Out:
# 49      231.57
# 48      240.78
# 47      245.59
# 46      248.89
# 45      251.58
# 44      253.25
# 43      280.27
# 42      285.82
# 41      289.56
# 40      324.73
# 39      327.98
# 38      332.45
# 37      349.66
# 36      364.78
# 35      364.92
# 34      369.76
# 33      370.89
# 32      373.75
# 31      385.14
# 30      408.61
# 29      411.83
# 28      418.88
# 27      443.25
# 26      477.67
# 25      483.74
# 24      562.23
# 23      600.77
# 22      613.30
# 21      614.19
# 20      625.92
# 19      741.69
# 18      748.00
# 17      909.89
# 16      945.33
# 15     1074.97
# 14     1212.83
# 13     1500.26
# 12     1506.44
# 11     1693.25
# 10     1719.90
# 9      1798.51
# 8      2138.92
# 7      2181.97
# 6      2848.23
# 5      2925.10
# 4      2936.29
# 3      4211.64
# 2      5167.05
# 1     14092.51
# 0     20412.87
# Name: National Income, dtype: float64

# %%
pd.Series(df["National Income"][1]).median()
# Out:
# 14092.51

# %%
df.sort_values("Growth", ascending=True)['Growth']
# Out:
# 29    0.53
# 18    0.74
# 30    0.82
# 8     0.98
# 19    1.07
# 33    1.32
# 7     1.47
# 43    1.47
# 10    1.55
# 2     1.71
# 24    1.71
# 39    1.77
# 4     1.79
# 27    1.81
# 5     1.85
# 14    2.04
# 34    2.11
# 0     2.27
# 13    2.27
# 23    2.40
# 49    2.51
# 3     2.51
# 46    2.67
# 22    2.79
# 20    2.86
# 26    2.90
# 41    2.99
# 9     3.00
# 12    3.05
# 11    3.09
# 16    3.11
# 32    3.32
# 37    3.62
# 36    3.82
# 25    3.90
# 44    4.23
# 28    4.28
# 45    4.29
# 21    4.55
# 15    5.07
# 40    5.28
# 35    5.90
# 38    6.67
# 6     6.74
# 48    6.81
# 1     6.86
# 47    7.00
# 17    7.05
# 42    7.14
# 31    7.81
# Name: Growth, dtype: float64

# %%
df.sort_values("Per person", ascending=True)['Per person']
# Out:
# 40     1615.0
# 21     1618.0
# 42     1734.0
# 30     2108.0
# 6      2135.0
# 18     2265.0
# 45     2375.0
# 48     2546.0
# 44     2611.0
# 38     3095.0
# 15     4052.0
# 28     5086.0
# 34     6383.0
# 33     6459.0
# 39     6581.0
# 25     6992.0
# 49     7199.0
# 14     9723.0
# 1     10088.0
# 8     10224.0
# 17    11114.0
# 35    11237.0
# 10    11947.0
# 47    12575.0
# 20    14044.0
# 43    15087.0
# 46    24237.0
# 22    25977.0
# 12    32559.0
# 11    32775.0
# 7     35914.0
# 29    39484.0
# 2     40849.0
# 32    42115.0
# 4     44177.0
# 5     44934.0
# 9     48466.0
# 36    48829.0
# 24    49272.0
# 3     50842.0
# 41    52422.0
# 26    53764.0
# 16    55185.0
# 23    58345.0
# 13    59655.0
# 37    61767.0
# 0     62152.0
# 31    80641.0
# 27    82711.0
# 19    86835.0
# Name: Per person, dtype: float64

# %%
features =['National Income','Growth','Per person']

# %%
df[features].hist(figsize=(10, 4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000B27D6C8>,
# ...
#       dtype=object)

# %% [markdown]
# In the above chart, we see that the variable growth, of each person, is distributed normally, while the total national income was at its highest and then declined to the lowest possible

# %%
sns.kdeplot(df["National Income"])

# %% [markdown]
# the most countries have a little national income, but a little countries has a large value of national income

# %%
sns.kdeplot(df["Per person"])

# %% [markdown]
# most Per person value has a  less than 15000 and little has an income per person more than this value,  a values of incoming per person has a medium percentage

# %%
sns.kdeplot(df["Growth"])

# %% [markdown]
# The most frequent Growth among [2,3]

# %%
df[df["Continent"]=="Africa"]
# Out:
#        Countries  National Income  Growth  Per person Continent
# 30       Nigeria           408.61    0.82      2108.0    Africa
# 33  South Africa           370.89    1.32      6459.0    Africa
# 44         Egypt           253.25    4.23      2611.0    Africa

# %%
sns.regplot(y=df["National Income"],x=df["Growth"])

# %% [markdown]
# I note that almost countries has little national income but little of others has a high national income

# %%
sns.regplot(y=df["National Income"],x=df["Per person"])

# %% [markdown]
# relationship between national income and per person is positive

# %%
sns.regplot(y=df["Per person"],x=df["Growth"])

# %% [markdown]
# relationship between growth and per person is inverse

# %%
sns.pairplot(df,corner=True)

# %%
g = sns.pairplot(df, diag_kind="kde")
g.map_lower(sns.kdeplot, levels=4, color=".2")

# %%
sns.pairplot(df)

# %% [markdown]
# I find high income per person with low national income. if country is a industrial country so it export it's product then it's growth will raise and others has a positive relationship

# %%
sns.pairplot(df,hue="Continent")
# Out:
# C:\nada anaconda\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\nada anaconda\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\nada anaconda\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# I find high income per person with low national income. and others has a positive relationship excludes relationship between per person and growth

# %%
pd.Series(df["National Income"]).median()
# Out:
# 522.985

# %%
sns.boxplot(x='National Income', data=df)

# %% [markdown]
# National Income's value focused between nearly 500,.. & 1900 it may be different because some countries depond on economy and other in agricultural(not industrial) little countries.
# median from above equals to 522.985
#
# We can see that a large number of National Income's is quite rare in our data.

# %%
sns.boxplot(y="Growth",x="Continent",data=df)

# %% [markdown]
# growth's smallest value less than zero because this country suffer economic crisis

# %%
sns.boxplot(x="Continent",y="National Income",data=df)

# %% [markdown]
#  I note Noth America has largest national income but the smallest value exist in South America and Africa.

# %%
sns.violinplot(y="Growth",x="Continent",data=df)

# %% [markdown]
# Smallest range of growth exist in Asia and highest one in North America

# %%
sns.violinplot(y="Per person",x="Continent",data=df)

# %% [markdown]
# frica has a largest range of per person feature, but the smallest one exist in Europe

# %%
sns.jointplot(x='Growth',y='Per person',data=df)

# %% [markdown]
# most country have low person have big growth

# %%
sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# National Income Increase when Person Increase by 0.16

# %%
plt.figure(figsize=(8, 12))
heatmap = sns.heatmap(df.corr()[['Per person']].sort_values(by='Per person', ascending=False),
                      vmin=-1, vmax=1, annot=True,cmap='BrBG')

# %% [markdown]
# The relationship between (individual and growth) is slightly greater than the relationship between (individual and national income). The relationship between the individual and the type of growth is: An inverse relationship between the individual and the type of national income is: a positive relationship
